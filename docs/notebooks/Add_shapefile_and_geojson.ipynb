# %% [markdown]
# ## new map instance

# %%
from geohmt import Map,shp_to_geojson

# %%
m = Map(center=[31.52,113.3],height="400px",zoom=12)
m
# Out:
# Map(center=[31.52, 113.3], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_o…

# %% [markdown]
# ## shp transform geojson

# %%
shp_path = r".\example\data\liulin_84.shp"
save_path = r".\example\data\liulin_84.geojson"
#".\example\data\liulin.shp"
shp_to_geojson(shp_path,savefile=save_path)
shp_to_geojson(shp_path)
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'OBJECTID': 1,
#     'Id': 1,
#     'gridcode': 1,
#     'Shape_Leng': 34198.9833972,
#     'Shape_Area': 25735939.6513},
#    'geometry': {'type': 'Polygon',
#     'coordinates': [[(113.22541240727851, 31.497272584173224),
#       (113.22500100301723, 31.497279740496),
#       (113.22500378675703, 31.497397243457968),
#       (113.22486665179946, 31.497399628616265),
#       (113.22486943538433, 31.49751713158677),
#       (113.22459516507791, 31.497521901484873),
#       (113.2245979483366, 31.497639404474842),
#       (113.22446081298776, 31.49764178921465),
#       (113.22446359609148, 31.497759292213168),
#       (113.22391505384844, 31.497768829748292),
#       (113.22391783628353, 31.497886332788095),
#       (113.2226836137438, 31.497907783753803),
#       (113.22268639465405, 31.498025286889444),
#       (113.22213785019527, 31.49803481687934),
# ...

# %% [markdown]
# ## add shapefiles

# %%
style = {
        "stroke" : True,
        "color" : "#000000",
        "weight" : 2,
        "opacity" : 1,
        "fill" : True,
        "fillColor" : "#000000",
        "fillOpacity" : 0.4,
    }

# %%
m.add_shapefile(shp_path,style=style,layer_name="shpfile")

# %% [markdown]
# ## add geojson

# %%
m.add_geojson(save_path,style=style,layer_name="geojson")
